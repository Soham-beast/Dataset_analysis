# %% [markdown]
# <a href="https://www.kaggle.com/code/mlbysoham/adult-dataset-analysis-with-supervised-mls?scriptVersionId=132917734" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **General information about dataset**
#
#
# This is one of the famous data sets for classification type of data analysis.
#
# Extraction was done by Barry Becker from the 1994 Census database.
# A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))
#
# Prediction task is to determine whether a person makes over 50K a year.
#
#
#
#
#
# **Listing of attributes:**
#
#
# **Salary:**>50K, <=50K.
#
# **age:** continuous.
#
# **workclass:** Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
#
# **fnlwgt:** continuous.
#
# **education:** Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
#
# **education-num:** continuous.
#
# **marital-status:** Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
#
# **occupation:** Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
#
# **relationship:** Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
#
# **race:** White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
#
# **sex:** Female, Male.
#
# **capital-gain:** continuous.
#
# **capital-loss:** continuous.
#
# **hours-per-week:** continuous.
#
# **native-country:** United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# **Packages Import**
#
# Here we will use the packages like **numpy** for mathematical operation; **pandas** for data cleaning, data inspection, statistical analysis and loading and saving data; **seaborn** will be used for plotting different types of graphs and see the analysis of different input attributes with the output attribute 'Salary' and the **matplotlib**  would also be used to create and display the plots

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#the different packages are imported and their names are converted to short ones

# %% [markdown]
# **Data wrangling/ Data reading**
#
# The data from the dataset is read and stored in a variable. Reading a dataset means to have a copy of it, that you can use while doing analysis.

# %%
adt = pd.read_csv(r'/kaggle/input/adult-dataset/adult.data',header=None,delimiter=' *, *',engine='python')
adt

#'header' makes the first row to come to the dataset and not get transfered to the column heading
#'delimiter' removes the blank spaces from front and back of each input data element
#'engine' defines the kernel engine as 'python' with which the data is fetched
# Out:
#        0                 1       2           3   4                   5   \
# 0      39         State-gov   77516   Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311   Bachelors  13  Married-civ-spouse
# 2      38           Private  215646     HS-grad   9            Divorced
# 3      53           Private  234721        11th   7  Married-civ-spouse
# 4      28           Private  338409   Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...         ...  ..                 ...
# 32556  27           Private  257302  Assoc-acdm  12  Married-civ-spouse
# 32557  40           Private  154374     HS-grad   9  Married-civ-spouse
# 32558  58           Private  151910     HS-grad   9             Widowed
# 32559  22           Private  201490     HS-grad   9       Never-married
# 32560  52      Self-emp-inc  287927     HS-grad   9  Married-civ-spouse
#
#                       6              7      8       9      10  11  12  \
# 0           Adm-clerical  Not-in-family  White    Male   2174   0  40
# 1        Exec-managerial        Husband  White    Male      0   0  13
# 2      Handlers-cleaners  Not-in-family  White    Male      0   0  40
# 3      Handlers-cleaners        Husband  Black    Male      0   0  40
# 4         Prof-specialty           Wife  Black  Female      0   0  40
# ...                  ...            ...    ...     ...    ...  ..  ..
# 32556       Tech-support           Wife  White  Female      0   0  38
# 32557  Machine-op-inspct        Husband  White    Male      0   0  40
# 32558       Adm-clerical      Unmarried  White  Female      0   0  40
# 32559       Adm-clerical      Own-child  White    Male      0   0  20
# 32560    Exec-managerial           Wife  White  Female  15024   0  40
#
#                   13     14
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4               Cuba  <=50K
# ...              ...    ...
# 32556  United-States  <=50K
# 32557  United-States   >50K
# 32558  United-States  <=50K
# 32559  United-States  <=50K
# 32560  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
adt.columns = ['age','work_class','fnlwgt','education','education_num','maritial_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','Salary']
adt

#renaming the header as not as indexes, but as attributes
# Out:
#        age        work_class  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#           maritial_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country Salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# **Data Cleaning**
#
# This the process where you find the missing/NULL values and replace them with suitable results. If too many missing datas are present in a column, you can even drop that column.

# %%
adt.isnull().sum()

#checks if any NULL values are present
#there were no NULL entries in any column, thus in every column it is 0
# Out:
# age                0
# work_class         0
# fnlwgt             0
# education          0
# education_num      0
# maritial_status    0
# occupation         0
# relationship       0
# race               0
# sex                0
# capital_gain       0
# capital_loss       0
# hours_per_week     0
# native_country     0
# Salary             0
# dtype: int64

# %%
adt.dtypes

#displays data type of each dataset column
#here we find that some of the numeric type columns have 'object' data type
# Out:
# age                 int64
# work_class         object
# fnlwgt              int64
# education          object
# education_num       int64
# maritial_status    object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital_gain        int64
# capital_loss        int64
# hours_per_week      int64
# native_country     object
# Salary             object
# dtype: object

# %%
adt.describe(include='all')

#used to describe each column statistically
#we found data error in 3 columns
# Out:
#                  age work_class        fnlwgt education  education_num  \
# count   32561.000000      32561  3.256100e+04     32561   32561.000000
# unique           NaN          9           NaN        16            NaN
# top              NaN    Private           NaN   HS-grad            NaN
# freq             NaN      22696           NaN     10501            NaN
# mean       38.581647        NaN  1.897784e+05       NaN      10.080679
# std        13.640433        NaN  1.055500e+05       NaN       2.572720
# min        17.000000        NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000        NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000        NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000        NaN  2.370510e+05       NaN      12.000000
# max        90.000000        NaN  1.484705e+06       NaN      16.000000
#
#            maritial_status      occupation relationship   race    sex  \
# count                32561           32561        32561  32561  32561
# unique                   7              15            6      5      2
# top     Married-civ-spouse  Prof-specialty      Husband  White   Male
# freq                 14976            4140        13193  27816  21790
# mean                   NaN             NaN          NaN    NaN    NaN
# std                    NaN             NaN          NaN    NaN    NaN
# min                    NaN             NaN          NaN    NaN    NaN
# 25%                    NaN             NaN          NaN    NaN    NaN
# 50%                    NaN             NaN          NaN    NaN    NaN
# 75%                    NaN             NaN          NaN    NaN    NaN
# max                    NaN             NaN          NaN    NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week native_country Salary
# count   32561.000000  32561.000000    32561.000000          32561  32561
# unique           NaN           NaN             NaN             42      2
# top              NaN           NaN             NaN  United-States  <=50K
# freq             NaN           NaN             NaN          29170  24720
# mean     1077.648844     87.303830       40.437456            NaN    NaN
# std      7385.292085    402.960219       12.347429            NaN    NaN
# min         0.000000      0.000000        1.000000            NaN    NaN
# 25%         0.000000      0.000000       40.000000            NaN    NaN
# 50%         0.000000      0.000000       40.000000            NaN    NaN
# 75%         0.000000      0.000000       45.000000            NaN    NaN
# max     99999.000000   4356.000000       99.000000            NaN    NaN

# %%
for i in adt.columns:
    print(i,'\n',adt[i].unique(),'\n')

#displays the unique data entry in each column
#with this we find that the missing data are represented by '?'
# Out:
# age
#  [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# work_class
#  ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
# fnlwgt
#  [ 77516  83311 215646 ...  34066  84661 257302]
#
# education
#  ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
#
# education_num
#  [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# maritial_status
#  ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
#
# occupation
#  ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' '?'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
#
# relationship
#  ['Not-in-family' 'Husband' 'Wife' 'Own-child' 'Unmarried' 'Other-relative']
#
# race
#  ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
#
# sex
#  ['Male' 'Female']
#
# capital_gain
#  [ 2174     0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386
#   7298  1409  3674  1055  3464  2050  2176   594 20051  6849  4101  1111
#   8614  3411  2597 25236  4650  9386  2463  3103 10605  2964  3325  2580
#   3471  4865 99999  6514  1471  2329  2105  2885 25124 10520  2202  2961
#  27828  6767  2228  1506 13550  2635  5556  4787  3781  3137  3818  3942
#    914   401  2829  2977  4934  2062  2354  5455 15020  1424  3273 22040
#   4416  3908 10566   991  4931  1086  7430  6497   114  7896  2346  3418
#   3432  2907  1151  2414  2290 15831 41310  4508  2538  3456  6418  1848
#   3887  5721  9562  1455  2036  1831 11678  2936  2993  7443  6360  1797
#   1173  4687  6723  2009  6097  2653  1639 18481  7978  2387  5060]
#
# capital_loss
#  [   0 2042 1408 1902 1573 1887 1719 1762 1564 2179 1816 1980 1977 1876
#  1340 2206 1741 1485 2339 2415 1380 1721 2051 2377 1669 2352 1672  653
#  2392 1504 2001 1590 1651 1628 1848 1740 2002 1579 2258 1602  419 2547
#  2174 2205 1726 2444 1138 2238  625  213 1539  880 1668 1092 1594 3004
#  2231 1844  810 2824 2559 2057 1974  974 2149 1825 1735 1258 2129 2603
#  2282  323 4356 2246 1617 1648 2489 3770 1755 3683 2267 2080 2457  155
#  3900 2201 1944 2467 2163 2754 2472 1411]
#
# hours_per_week
#  [40 13 16 45 50 80 30 35 60 20 52 44 15 25 38 43 55 48 58 32 70  2 22 56
#  41 28 36 24 46 42 12 65  1 10 34 75 98 33 54  8  6 64 19 18 72  5  9 47
#  37 21 26 14  4 59  7 99 53 39 62 57 78 90 66 11 49 84  3 17 68 27 85 31
#  51 77 63 23 87 88 73 89 97 94 29 96 67 82 86 91 81 76 92 61 74 95]
#
# native_country
#  ['United-States' 'Cuba' 'Jamaica' 'India' '?' 'Mexico' 'South'
#  'Puerto-Rico' 'Honduras' 'England' 'Canada' 'Germany' 'Iran'
#  'Philippines' 'Italy' 'Poland' 'Columbia' 'Cambodia' 'Thailand' 'Ecuador'
#  'Laos' 'Taiwan' 'Haiti' 'Portugal' 'Dominican-Republic' 'El-Salvador'
#  'France' 'Guatemala' 'China' 'Japan' 'Yugoslavia' 'Peru'
#  'Outlying-US(Guam-USVI-etc)' 'Scotland' 'Trinadad&Tobago' 'Greece'
#  'Nicaragua' 'Vietnam' 'Hong' 'Ireland' 'Hungary' 'Holand-Netherlands']
#
# Salary
#  ['<=50K' '>50K']

# %%
for i in adt.columns:
    print(i,':',sum(adt[i]=='?'))

#check the number of '?' present in each column
# Out:
# age : 0
# work_class : 1836
# fnlwgt : 0
# education : 0
# education_num : 0
# maritial_status : 0
# occupation : 1843
# relationship : 0
# race : 0
# sex : 0
# capital_gain : 0
# capital_loss : 0
# hours_per_week : 0
# native_country : 583
# Salary : 0

# %%
d1=adt.describe(include='all')
d1 

#d1 stores the description of all the columns of the dataset
#this is used to replace NULL values of the dataset
# Out:
#                  age work_class        fnlwgt education  education_num  \
# count   32561.000000      32561  3.256100e+04     32561   32561.000000
# unique           NaN          9           NaN        16            NaN
# top              NaN    Private           NaN   HS-grad            NaN
# freq             NaN      22696           NaN     10501            NaN
# mean       38.581647        NaN  1.897784e+05       NaN      10.080679
# std        13.640433        NaN  1.055500e+05       NaN       2.572720
# min        17.000000        NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000        NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000        NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000        NaN  2.370510e+05       NaN      12.000000
# max        90.000000        NaN  1.484705e+06       NaN      16.000000
#
#            maritial_status      occupation relationship   race    sex  \
# count                32561           32561        32561  32561  32561
# unique                   7              15            6      5      2
# top     Married-civ-spouse  Prof-specialty      Husband  White   Male
# freq                 14976            4140        13193  27816  21790
# mean                   NaN             NaN          NaN    NaN    NaN
# std                    NaN             NaN          NaN    NaN    NaN
# min                    NaN             NaN          NaN    NaN    NaN
# 25%                    NaN             NaN          NaN    NaN    NaN
# 50%                    NaN             NaN          NaN    NaN    NaN
# 75%                    NaN             NaN          NaN    NaN    NaN
# max                    NaN             NaN          NaN    NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week native_country Salary
# count   32561.000000  32561.000000    32561.000000          32561  32561
# unique           NaN           NaN             NaN             42      2
# top              NaN           NaN             NaN  United-States  <=50K
# freq             NaN           NaN             NaN          29170  24720
# mean     1077.648844     87.303830       40.437456            NaN    NaN
# std      7385.292085    402.960219       12.347429            NaN    NaN
# min         0.000000      0.000000        1.000000            NaN    NaN
# 25%         0.000000      0.000000       40.000000            NaN    NaN
# 50%         0.000000      0.000000       40.000000            NaN    NaN
# 75%         0.000000      0.000000       45.000000            NaN    NaN
# max     99999.000000   4356.000000       99.000000            NaN    NaN

# %%
for i in ['work_class','occupation','native_country']:
    adt[i].replace('?',d1[i][2],inplace=True)
    
#replaces the column elements with the top repeated element in the describe table

# %%
for i in adt.columns:
    print(i,':',sum(adt[i]=='?'))
    
#checks if any more '?' is present in any of the columns
# Out:
# age : 0
# work_class : 0
# fnlwgt : 0
# education : 0
# education_num : 0
# maritial_status : 0
# occupation : 0
# relationship : 0
# race : 0
# sex : 0
# capital_gain : 0
# capital_loss : 0
# hours_per_week : 0
# native_country : 0
# Salary : 0

# %%
adt = adt.drop('fnlwgt',axis=1)     
adt

#dropping the column that is pre-assumed to be not required
#'fnlwgt' has unordered data, that has no use and has no relation with the output 'Salary'
# Out:
#        age        work_class   education  education_num     maritial_status  \
# 0       39         State-gov   Bachelors             13       Never-married
# 1       50  Self-emp-not-inc   Bachelors             13  Married-civ-spouse
# 2       38           Private     HS-grad              9            Divorced
# 3       53           Private        11th              7  Married-civ-spouse
# 4       28           Private   Bachelors             13  Married-civ-spouse
# ...    ...               ...         ...            ...                 ...
# 32556   27           Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40           Private     HS-grad              9  Married-civ-spouse
# 32558   58           Private     HS-grad              9             Widowed
# 32559   22           Private     HS-grad              9       Never-married
# 32560   52      Self-emp-inc     HS-grad              9  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital_gain  \
# 0           Adm-clerical  Not-in-family  White    Male          2174
# 1        Exec-managerial        Husband  White    Male             0
# 2      Handlers-cleaners  Not-in-family  White    Male             0
# 3      Handlers-cleaners        Husband  Black    Male             0
# 4         Prof-specialty           Wife  Black  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556       Tech-support           Wife  White  Female             0
# 32557  Machine-op-inspct        Husband  White    Male             0
# 32558       Adm-clerical      Unmarried  White  Female             0
# 32559       Adm-clerical      Own-child  White    Male             0
# 32560    Exec-managerial           Wife  White  Female         15024
#
#        capital_loss  hours_per_week native_country Salary
# 0                 0              40  United-States  <=50K
# 1                 0              13  United-States  <=50K
# 2                 0              40  United-States  <=50K
# 3                 0              40  United-States  <=50K
# 4                 0              40           Cuba  <=50K
# ...             ...             ...            ...    ...
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K
#
# [32561 rows x 14 columns]

# %% [markdown]
# **Data Analysis**
#
# The input data are graphically compared to the output data, and a rigorous analysis is done over those plots, to find out the input columns that are not necessary for our output 'Salary'.
#
# Different types of plots are tried in case one plot does not yeild much clear vision on the relation.
#
# Further it is advised to have a general knowledge about the relation between the input data and the output data, before dropping the columns.

# %%
#heatmap-> to view the linear correlation of different numeric attributes with each other 

cor=adt.corr()     
#stores the correlation between different attributes

sns.heatmap(cor,annot=True,cmap='YlGnBu')
plt.title('Heat Map')
plt.show()

#it can be seen that as our output column is in 'object' type, thus not present in heatmap
#heatmaps are generally not preferred for 'object' type of outputs
#the correlation displayed on the heatmap is only for linear, thus an attribute with low correlation can also be important
#thus disregarding 'heatmap' and proceeding further with other types of analysis
# Out:
# /tmp/ipykernel_20/4142613857.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=adt.corr()

# %% [markdown]
# ***Analysis between age and salary***

# %%
adt.age.unique()

#this shows that the 'age' attribute is continuous in nature
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87])

# %%
#undertaking hist,scatter, split, violin, box and kde plots

sns.kdeplot(adt.age[adt.Salary=='>50K'])     
#shows the kernel density estimation for more than 50K salary

sns.kdeplot(adt.age[adt.Salary=='<=50K'])    
#shows the kernel density estimation for less than 50K salary

plt.legend(['More salary','Less salary'])
plt.title('KDE Plot')
plt.show()

#the below data shows a variation over different age groups, for their salary
#it shows that the people with age near '20' most likely have less than 50K salary
#also it shows that the people with age near '40' most likely have more than 50K salary

# %%
sns.kdeplot(x=adt.age,hue=adt.Salary)       
#simultaneoulsy display kernel densities of both 'Salary' groups, based on 'age'

plt.title('KDE Plot')
plt.show()

#the below data shows a variation over different age groups, for their salary
#the data for the people with salary more than 50K is much less in comparison
#it shows that the people with age near '20' most likely have less than 50K salary
#also it shows that the people with age near '40' most likely have more than 50K salary

# %%
sns.scatterplot(x=adt.age,y=adt.Salary,marker='o')
#points are marked where the data is present for the two attributes

plt.title('Scatter Plot')
plt.show()

#the plot is not very clear, but it can be derived from the plot that the 'Salary' attributes have different distributions
#the densities of the points at '<=50K' is more as compared to '>50K' category over 'age' attribute
#more number of people are having 'Salary' less than 50K

# %%
plt.figure(figsize=(20,15))
sns.stripplot(x=adt.age,y=adt.Salary,data=adt)
#the plotting is for both the categories of 'Salary', strip-wise

plt.title('Strip Plot')
plt.show()

#the graph from the strip plot is also not much clear, except for the categorical densities

# %%
plt.figure(figsize=(20,15))
sns.violinplot(x=adt.age,y=adt.Salary,data=adt)
#the plotting is for both the categories of 'Salary', in a mixture of kde and box plots

plt.title('Violin Plot')
plt.show()

#the graph from the violin plot is much clear, for the categorical densities
#notable density concentration of '<=50K' occurs near age 20, while for '>50K' occurs near 40

# %%
plt.figure(figsize=(20,15))
sns.boxplot(x=adt.Salary,y=adt.age,data=adt)
#the plotting is for both the categories of 'Salary', in a mixture of kde and box plots

plt.title('Box Plot')
plt.show()

#the graph from the box plot is much clear, for the mean of the categorical densities
#mean of '<=50K' occurs near age 33, while for '>50K' occurs near 44
#both the categories of data of 'Salary' attribute have outliers

# %%
sns.histplot(x=adt.age,hue=adt.Salary)       
#simultaneoulsy display histogram of both salary groups

plt.title('Histogram')
plt.show()

#the below data shows a variation over different age groups, for their salary
#the data for the people with salary more than 50K is much less in comparison
#it shows that the people with age near '20' most likely have less than 50K salary
#also it shows that the people with age near '40' most likely have more than 50K salary


# thus the 'age' attribute needs to be kept for model training

# %% [markdown]
# **Analysis between workclass and salary**

# %%
adt.work_class.unique()

#the data in 'work_class' is object in nature and categorical
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
adt.work_class.nunique()

#the data in 'work_class' categorical, with 8 unique values
# Out:
# 8

# %%
#undertaking count plot

plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.countplot(x=adt.work_class,hue=adt.Salary)        
#used to count the unique entries of 'work_class' attribute, based on the 'Salary' attribute

plt.title('Count Plot')
plt.show()

#the plot shows a huge variation in 'Salary' with respect to the 'work_class'
#the peak number of entries for both '>50K' and '<=50K' happens to be at 'private'
#already the count plot has shown visible variation, thus no more plotting is needed

# thus the 'work_class' attribute needs to be kept for model training

# %% [markdown]
# **Analysis between education and salary**

# %%
adt.education.unique()

#the data in 'education' is object in nature and categorical
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
adt.education.nunique()

#the data in 'education' categorical, with 16 unique values, thus to be considered as mix of continuous and categorical
# Out:
# 16

# %%
#undertaking hist, count and kde plots

plt.figure(figsize=(20,15))                        
#used to enlarge the plot size to be easy to be viewed

sns.histplot(x=adt.education,hue=adt.Salary)
#used to plot the histogram of the unique entries of 'education' attribute, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#the plot shows variation, but the bar columns are over-lapping, thus needs further clarification
#the peak of the '<=50K' from the 'Salary' attribute happens to be at 'HS-grad' from 'education' attribute
#the peak of the '>50K' from the 'Salary' attribute happens to be at 'bachelors' from 'education' attribute

#if more number of hue is present and the overlap is not clear, we use 'displot'

# %%
plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.countplot(x=adt.education,hue=adt.Salary)        
#used to count the unique entries of 'education' attribute, based on the 'Salary' attribute

plt.title('Count Plot')
plt.show()

#the plot shows a huge variation in 'Salary' with respect to the 'education' and is clearly shown
#the peak of the '<=50K' from the 'Salary' attribute happens to be at 'HS-grad' from 'education' attribute
#the peak of the '>50K' from the 'Salary' attribute happens to be at 'bachelors' from 'education' attribute

# %%
#sns.kdeplot(x=adt.education,hue=adt.Salary)       
#simultaneoulsy display kernel densities of both salary groups, based on their 'education' attribute

#plt.show()

#kde plot is possible for numeric datas only and not for the object data
#datetime is also an allowed 'x' argument for kernel densities

#based on the variations got in histogram and countplot, we keep the data from the 'education' attribute

# %% [markdown]
# **Analysis between education_num and salary**

# %%
adt.education_num.unique()

#the data in 'education_num' is object in nature and categorical
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8])

# %%
adt.education_num.nunique()

#the data in 'education_num' categorical, with 16 unique values
#thus it to be considered as mix of continuous and categorical
# Out:
# 16

# %%
#undertaking hist, count, scatter, strip, violin and kde plots

plt.figure(figsize=(20,15))                        
#used to enlarge the plot size to be easy to be viewed

sns.histplot(x=adt.education_num,hue=adt.Salary)
#used to plot the histogram of the unique entries of 'education_num' attribute, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#the plot shows variation, but the bar columns are over-lapping, thus needs further clarification
#the peak of the '<=50K' from the 'Salary' attribute happens to be at '9' from 'education_num' attribute
#the peak of the '>50K' from the 'Salary' attribute happens to be at '13' from 'education_num' attribute

#if more number of hue is present and the overlap is not clear, we use 'displot'

# %%
plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.countplot(x=adt.education_num,hue=adt.Salary)        
#used to count the unique entries of 'education_num' attribute, based on the 'Salary' attribute

plt.title('Count Plot')
plt.show()

#the plot shows a huge variation in 'Salary' with respect to the 'education_num' and is clearly shown
#the peak of the '<=50K' from the 'Salary' attribute happens to be at '9' from 'education_num' attribute
#the peak of the '>50K' from the 'Salary' attribute happens to be at '13' from 'education_num' attribute

# %%
sns.scatterplot(x=adt.education_num,y=adt.Salary,marker='o')
#points are marked at locations where data from both the attributes are present

plt.title('Scatter Plot')
plt.show()

#the plot is not very clear, but it can be derived from the plot that the 'Salary' attributes have different distributions
#the densities of the points at '<=50K' is slighty more as compared to '>50K' category over 'education_num' attribute
#more number of people are having 'Salary' less than 50K

# %%
plt.figure(figsize=(20,15))
sns.stripplot(x=adt.education_num,y=adt.Salary,data=adt)
#the plotting is for both the categories of 'Salary', strip-wise

plt.title('Strip Plot')
plt.show()

#the graph from the strip plot is also not much clear, except for the categorical densities
#a notable observation is that at 'education_num' of 2, the 'Salary' of '>50K' is less in comparison

# %%
plt.figure(figsize=(20,15))
sns.violinplot(x=adt.education_num,y=adt.Salary,data=adt)
#the plotting is for both the categories of 'Salary', in a mixture of kde and box plots

plt.title('Violin Plot')
plt.show()

#the graph from the violin plot is much clear, for the categorical densities
#this also shows a clear and visible variation in the categories

# %%
sns.kdeplot(x=adt.education_num,hue=adt.Salary)       
#simultaneoulsy display kernel densities of both salary groups, based on their 'education' attribute

plt.title('KDE Plot')
plt.show()

#kde plot shows a clear variation in graph shape
#the peak of the graph is near '8' of 'education_num' attribute for '<=50K' for 'Salary' attribute
#the peak of the graph is near '13' of 'education_num' attribute for '>50K' for 'Salary' attribute


#based on all the variations got in histogram, kde and countplot, we keep the data from the 'education_num' attribute

# %% [markdown]
# **Analysis between maritial_status and salary**

# %%
adt.maritial_status.unique()

#the 'maritial_status' attribute is object type and is categorical in nature
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Divorced',
#        'Married-spouse-absent', 'Separated', 'Married-AF-spouse',
#        'Widowed'], dtype=object)

# %%
adt.maritial_status.nunique()

#total number of unique categories in 'maritial_status' attribute is 7
# Out:
# 7

# %%
#undertaking hist and count plots

plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.histplot(x=adt.maritial_status,hue=adt.Salary)
#used to plot the histogram of the unique entries of 'maritial_status' attribute, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#a clear variation can be observed, but still the graph is much overlapped
#the peak of '<=50K' for 'Salary' attribute can be found at 'Never-married' bar for 'maritial_status' attribute
#the peak of '>50K' for 'Salary' attribute can be found at 'Married-civ-spouse' bar for 'maritial_status' attribute

# %%
plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.countplot(x=adt.maritial_status,hue=adt.Salary)        
#used to count the unique entries of 'maritial_status' attribute, based on the 'Salary' attribute

plt.title('Count Plot')
plt.show()

#the plot shows a huge variation in 'Salary' with respect to the 'maritial_status' and is clearly shown
#the peak of the '<=50K' from the 'Salary' attribute happens to be at 'Never-married' from 'maritial_status' attribute
#the peak of the '>50K' from the 'Salary' attribute happens to be at 'Married-civ-spouse' from 'maritial_status' attribute


#based on the data from hist and count plots, 'maritial_status' would be kept for model training

# %% [markdown]
# **Analysis between occupation and salary**

# %%
adt.occupation.unique()

#the data of 'occupation' is categorical, but have large number of unique entries
# Out:
# array(['Adm-clerical', 'Exec-managerial', 'Handlers-cleaners',
#        'Prof-specialty', 'Other-service', 'Sales', 'Craft-repair',
#        'Transport-moving', 'Farming-fishing', 'Machine-op-inspct',
#        'Tech-support', 'Protective-serv', 'Armed-Forces',
#        'Priv-house-serv'], dtype=object)

# %%
adt.occupation.nunique()

#total number of unique entries for 'occupation' is 14
# Out:
# 14

# %%
#undertaking hist and count plots

plt.figure(figsize=(30,25))                           
#used to enlarge the plot size to be easy to be viewed

sns.histplot(x=adt.occupation,hue=adt.Salary)
#used to plot the histogram of the unique entries of 'occupation' attribute, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#a clear variation can be observed, but still the graph is much overlapped
#both the peak of the entries of '>50K' and '<=50K' for 'Salary' attribute can be found at 'Prof-specialty' bar for 'occupation' attribute

# %%
#undertaking hist and count plots

plt.figure(figsize=(30,25))                           
#used to enlarge the plot size to be easy to be viewed

sns.histplot(x=adt.occupation,hue=adt.Salary)
#used to plot the histogram of the unique entries of 'occupation' attribute, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#a clear variation can be observed, but still the graph is much overlapped
#both the peak of the entries of '>50K' and '<=50K' for 'Salary' attribute can be found at 'Prof-specialty' bar for 'occupation' attribute

# %% [markdown]
# **Analysis between relationship and salary**

# %%
adt.relationship.unique()

#the data is categorical in nature, with finite entries
# Out:
# array(['Not-in-family', 'Husband', 'Wife', 'Own-child', 'Unmarried',
#        'Other-relative'], dtype=object)

# %%
adt.relationship.nunique()

#the total number of unique entries is 6
# Out:
# 6

# %%
#undertaking hist and count plots

plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.histplot(x=adt.relationship,hue=adt.Salary)
#used to plot the histogram of the unique entries of 'relationship' attribute, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#a clear variation can be observed, but still the graph is much overlapped
#the peak of the '<=50K' from the 'Salary' attribute happens to be at 'Not-in-family' from 'relationship' attribute
#the peak of the '>50K' from the 'Salary' attribute happens to be at 'Husband' from 'relationship' attribute

# %%
plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.countplot(x=adt.relationship,hue=adt.Salary)        
#used to count the unique entries of 'relationship' attribute, based on the 'Salary' attribute

plt.title('Count Plot')
plt.show()

#the plot shows a huge variation in 'Salary' with respect to the 'relationship' and is clearly shown
#the peak of the '<=50K' from the 'Salary' attribute happens to be at 'Not-in-family' from 'relationship' attribute
#the peak of the '>50K' from the 'Salary' attribute happens to be at 'Husband' from 'relationship' attribute

#based on the data from hist and count plots, 'relationship' would be kept for model training

# %% [markdown]
# **Analysis between race and salary**

# %%
adt.race.unique()

#the data is categorical and is finite in number
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %%
adt.race.nunique()

#the total number of unique entries is 5
# Out:
# 5

# %%
#undertaking hist, scatter and count plots

plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.histplot(x=adt.race,hue=adt.Salary)
#used to plot the histogram of the unique entries of 'race' attribute, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#a clear variation can be observed, but still the graph is much overlapped
#both the peak of the entries of '>50K' and '<=50K' for 'Salary' attribute can be found at 'white' bar for 'race' attribute

# %%
plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.countplot(x=adt.race,hue=adt.Salary)        
#used to count the unique entries of 'relationship' attribute, based on the 'Salary' attribute

plt.title('Count Plot')
plt.show()

#the plot shows a huge variation in 'Salary' with respect to the 'race' and is clearly shown
#both the peak of the entries of '>50K' and '<=50K' for 'Salary' attribute can be found at 'white' bar for 'race' attribute

# %%
plt.figure(figsize=(20,15))           
#used to enlarge the plot so that the plotted points are clearly visible

sns.scatterplot(x=adt.race,y=adt.Salary,data=adt)
#the points are plotted, where the data for both the attributes is present

plt.title('Scatter Plot')
plt.show()

#no clear variation can be observed in scatter plot


#based on the hist and count plots, the data from 'race' attribute is to be considered for model training

# %% [markdown]
# **Analysis between sex and salary**

# %%
adt.sex.unique()

#only 2 unique categorical entries were present in the 'sex' attribute
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#undertaking hist and count plots

plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.histplot(x=adt.sex,hue=adt.Salary)
#used to plot the histogram of the unique entries of 'sex' attribute, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#a clear variation can be observed, but still the graph is much overlapped
#'male' category has the peak for both the '>50K' and '<=50K' of 'Salary' attribute

# %%
plt.figure(figsize=(20,15))                           
#used to enlarge the plot size to be easy to be viewed

sns.countplot(x=adt.sex,hue=adt.Salary)        
#used to count the unique entries of 'sex' attribute, based on the 'Salary' attribute

plt.title('Count Plot')
plt.show()

#the plot shows a huge variation in 'Salary' with respect to the 'sex' and is clearly shown
#'male' category has the peak for both the '>50K' and '<=50K' of 'Salary' attribute


#based on the data from hist and count plots, 'sex' would be kept for model training

# %% [markdown]
# **Analysis between capital_gain and salary**

# %%
adt.capital_gain.unique()

#the data is continuous in nature
# Out:
# array([ 2174,     0, 14084,  5178,  5013,  2407, 14344, 15024,  7688,
#        34095,  4064,  4386,  7298,  1409,  3674,  1055,  3464,  2050,
#         2176,   594, 20051,  6849,  4101,  1111,  8614,  3411,  2597,
#        25236,  4650,  9386,  2463,  3103, 10605,  2964,  3325,  2580,
#         3471,  4865, 99999,  6514,  1471,  2329,  2105,  2885, 25124,
#        10520,  2202,  2961, 27828,  6767,  2228,  1506, 13550,  2635,
#         5556,  4787,  3781,  3137,  3818,  3942,   914,   401,  2829,
#         2977,  4934,  2062,  2354,  5455, 15020,  1424,  3273, 22040,
#         4416,  3908, 10566,   991,  4931,  1086,  7430,  6497,   114,
#         7896,  2346,  3418,  3432,  2907,  1151,  2414,  2290, 15831,
#        41310,  4508,  2538,  3456,  6418,  1848,  3887,  5721,  9562,
#         1455,  2036,  1831, 11678,  2936,  2993,  7443,  6360,  1797,
#         1173,  4687,  6723,  2009,  6097,  2653,  1639, 18481,  7978,
#         2387,  5060])

# %%
#undertaking kde, dis, violin, box and line plots

plt.figure(figsize=(20,15))       #for enlarging the plot so that the curve is visible
sns.kdeplot(x=adt.capital_gain,hue=adt.Salary)
plt.title('KDE Plot')
plt.show()

#the variation is only observable at the neighborhood of '0' entry of 'capital_gain'
#at the neighbrhood of 0, the spike for '<=50K' is more than that of '>50K'
#there seems to be lack of data of the 'capital_gain' attribute

# %%
plt.figure(figsize=(20,15))
sns.displot(x=adt.capital_gain,hue=adt.Salary)
#a histogram is constructed for the count of each data entry, based on the 'Salary' attribute
plt.title('Histogram')
plt.show()

#the variation is only observable at the neighborhood of '0' entry of 'capital_gain'
#at the neighbrhood of 0, the spike for '<=50K' is more than that of '>50K', and both occur at same point
#there seems to be more '>50k' entries for 'capital_gain' of 10000-20000

# %%
plt.figure(figsize=(20,15))              
#to enlarge the figure for plots to be visible

sns.violinplot(x=adt.Salary,y=adt.capital_gain,data=adt)
#give a mix of kde and box plots for the attribute 'capital_gain', based on 'Salary'

plt.title('Violin Plot')
plt.show()

#both the categories of 'Salary' attribute have high densities in the neighborhood of '0'
#the number of outliers for '>50K' is more than that of '<=50K'
#the entries for '>50K' is concentrated near '>50K'
#the entires for '<=50K' is much distributed

# %%
sns.lineplot(x=adt.Salary,y=adt.capital_gain,data=adt)
#plots a line between the 2 attributes based on the matching entries

plt.title('Line Plot')
plt.show()

#as no 'hue' parameter is given, improper plotting is displayed, no conclusion can be drawn

# %%
plt.figure(figsize=(30,25))              
#to enlarge the figure for plots to be visible

sns.boxplot(x=adt.Salary,y=adt.capital_gain,data=adt)
#give a mix of kde and box plots for the attribute 'capital_gain', based on 'Salary'

plt.title('Box Plot')
plt.show()

#both the categories of 'Salary' attribute have concentrated densities at '0'
#the number of outliers for '>50K' is more than that of '<=50K'
#also the highest value of outliers for '>50K' is more than that of '<=50K'

#the 'capital_gain' attribute may be considered for model training, but can also be dropped to increase accuracy

# %% [markdown]
# **Analysis between capital_loss and salary**

# %%
adt.capital_loss.unique()

#the data is continuous in nature
# Out:
# array([   0, 2042, 1408, 1902, 1573, 1887, 1719, 1762, 1564, 2179, 1816,
#        1980, 1977, 1876, 1340, 2206, 1741, 1485, 2339, 2415, 1380, 1721,
#        2051, 2377, 1669, 2352, 1672,  653, 2392, 1504, 2001, 1590, 1651,
#        1628, 1848, 1740, 2002, 1579, 2258, 1602,  419, 2547, 2174, 2205,
#        1726, 2444, 1138, 2238,  625,  213, 1539,  880, 1668, 1092, 1594,
#        3004, 2231, 1844,  810, 2824, 2559, 2057, 1974,  974, 2149, 1825,
#        1735, 1258, 2129, 2603, 2282,  323, 4356, 2246, 1617, 1648, 2489,
#        3770, 1755, 3683, 2267, 2080, 2457,  155, 3900, 2201, 1944, 2467,
#        2163, 2754, 2472, 1411])

# %%
#undertaking kde, dis, strip, violin and box plots

plt.figure(figsize=(20,15))       
#for enlarging the plot so that the curve is visible

sns.kdeplot(x=adt.capital_loss,hue=adt.Salary)
plt.title('KDE Plot')
plt.show()

#the variation is only observable at the neighborhood of '0' entry of 'capital_loss'
#at the neighbrhood of 0, the spike for '<=50K' is more than that of '>50K'
#there seems to be lack of data of the 'capital_loss' attribute

# %%
sns.stripplot(x=adt.capital_loss,y=adt.Salary,data=adt)
#gives a plot of densities of points in the form of strips

plt.title('Strip Plot')
plt.show()

#the density of '>50K' is less than that of '<=50K' for given 'capital_loss' attribute values

# %%
plt.figure(figsize=(20,15))
sns.displot(x=adt.capital_loss,hue=adt.Salary)
#a histogram is constructed for the count of each data entry, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#the variation is only observable at the neighborhood of '0' entry of 'capital_loss'
#at the neighbrhood of 0, the spike for '<=50K' is more than that of '>50K', and both occur at same point
#there seems to be more '>50k' entries for 'capital_loss' of 1400-2300

# %%
plt.figure(figsize=(20,15))              
#to enlarge the figure for plots to be visible

sns.violinplot(x=adt.Salary,y=adt.capital_loss,data=adt)
#give a mix of kde and box plots for the attribute 'capital_loss', based on 'Salary'

plt.title('Violin Plot')
plt.show()

#both the categories of 'Salary' attribute have high densities in the neighborhood of '0'
#the number of outliers for '>50K' is more than that of '<=50K'
#at '2000' of 'capital_loss', the entries for '>50K' is relatively more

# %%
plt.figure(figsize=(20,15))              
#to enlarge the figure for plots to be visible

sns.boxplot(x=adt.Salary,y=adt.capital_loss,data=adt)
#give a mix of kde and box plots for the attribute 'capital_loss', based on 'Salary'

plt.title('Box Plot')
plt.show()

#both the categories of 'Salary' attribute have concentrated densities at '0'
#the number of outliers for '>50K' is less than that of '<=50K'
#also the highest value of outliers for '>50K' is less than that of '<=50K'

#the 'capital_loss' attribute may be considered for model training, but can also be dropped to increase accuracy

# %% [markdown]
# **Analysis between hours per week and salary**

# %%
adt.hours_per_week.unique()

#the data is continuous in nature
# Out:
# array([40, 13, 16, 45, 50, 80, 30, 35, 60, 20, 52, 44, 15, 25, 38, 43, 55,
#        48, 58, 32, 70,  2, 22, 56, 41, 28, 36, 24, 46, 42, 12, 65,  1, 10,
#        34, 75, 98, 33, 54,  8,  6, 64, 19, 18, 72,  5,  9, 47, 37, 21, 26,
#        14,  4, 59,  7, 99, 53, 39, 62, 57, 78, 90, 66, 11, 49, 84,  3, 17,
#        68, 27, 85, 31, 51, 77, 63, 23, 87, 88, 73, 89, 97, 94, 29, 96, 67,
#        82, 86, 91, 81, 76, 92, 61, 74, 95])

# %%
#undertaking kde, dis, strip, violin and box plots

plt.figure(figsize=(20,15))       
#for enlarging the plot so that the curve is visible

sns.kdeplot(x=adt.hours_per_week,hue=adt.Salary)
plt.title('KDE Plot')
plt.show()

#there is a clear variation visible, in terms of kernel densities
#at the neighbrhood of 40, the spike for '<=50K' is more than that of '>50K'

# %%
sns.stripplot(x=adt.hours_per_week,y=adt.Salary,data=adt)
#gives a plot of densities of points in the form of strips

plt.title('Strip Plot')
plt.show()

#the density of '>50K' is less than that of '<=50K' for given 'hours_per_week' attribute values

# %%
plt.figure(figsize=(40,30))
sns.histplot(x=adt.hours_per_week,hue=adt.Salary)
#a histogram is constructed for the count of each data entry, based on the 'Salary' attribute

plt.title('Histogram')
plt.show()

#the variation is not clearly observable, due to small enlargement
#at t'40', the spike for '<=50K' is more than that of '>50K'

# %%
plt.figure(figsize=(20,15))              
#to enlarge the figure for plots to be visible

sns.violinplot(x=adt.Salary,y=adt.hours_per_week,data=adt)
#give a mix of kde and box plots for the attribute 'hours_per_week', based on 'Salary'

plt.title('Violin Plot')
plt.show()

#both the categories of 'Salary' attribute have high densities in the neighborhood of '40'
#the variation in the kernel densities for both the categories of 'Salary' attribute is clearly visible

# %%
plt.figure(figsize=(20,15))              
#to enlarge the figure for plots to be visible

sns.boxplot(x=adt.Salary,y=adt.hours_per_week,data=adt)
#give a mix of kde and box plots for the attribute 'hours_per_week', based on 'Salary'

plt.title('Box Plot')
plt.show()

#both the categories of 'Salary' attribute have different mean, min and max values
#the variation of data is clearly visible


#the 'hours_per_week' attribute can be considered for model training

# %% [markdown]
# **Analysis between native country and salary**

# %%
adt.native_country.unique()

#the data is categorical, but has huge quantity
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', 'Mexico', 'South',
#        'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany', 'Iran',
#        'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
adt.native_country.nunique()

#there are a total of 41 unique entries
# Out:
# 41

# %%
#undertaking the countplot
plt.figure(figsize=(50,45))                           
#used to enlarge the plot size to be easy to be viewed

sns.countplot(x=adt.native_country,hue=adt.Salary)        
#used to count the unique entries of 'native_country' attribute, based on the 'Salary' attribute

plt.title('Count Plot')
plt.show()

#the plot shows a huge variation in 'Salary' with respect to the 'native_country'
#'United-States' category has the peak for both the '>50K' and '<=50K' of 'Salary' attribute
#the 'native_country' attributes lacks required amount of data


#based on the data from hist and count plots, 'native_country' would be kept for model training

# %% [markdown]
# **Model Training Using Linear Regression**
#
# Linear Regression is used only for continuous data.
#
# This implementation will prove the above point.
#
# The string data in input columns should be converted to numerics using 'Label Encoding' to enable Linear Model.

# %% [markdown]
# **Label Encoding**
#
# Each string data is assigned a numeric value from 0 to (n-1), based on the index-wise occurence of data.

# %%
from sklearn import preprocessing
le1 = preprocessing.LabelEncoder()           #label encoder variable for 'work_class'
adt.work_class = le1.fit_transform(adt.work_class)

le2 = preprocessing.LabelEncoder()           #label encoder variable for 'education'
adt.education = le2.fit_transform(adt.education)

le3 = preprocessing.LabelEncoder()           #label encoder variable for 'maritial_status'
adt.maritial_status = le3.fit_transform(adt.maritial_status)

le4 = preprocessing.LabelEncoder()           #label encoder variable for 'occupation'
adt.occupation = le4.fit_transform(adt.occupation)

le5 = preprocessing.LabelEncoder()           #label encoder variable for 'relationship'
adt.relationship = le5.fit_transform(adt.relationship)

le6 = preprocessing.LabelEncoder()           #label encoder variable for 'race'
adt.race = le6.fit_transform(adt.race)

le7 = preprocessing.LabelEncoder()           #label encoder variable for 'sex'
adt.sex = le7.fit_transform(adt.sex)

le8 = preprocessing.LabelEncoder()           #label encoder variable for 'native_country'
adt.native_country = le8.fit_transform(adt.native_country)


#it is always a good practice to use separate encoder variables, as then the data stored can easily be inversed

# %% [markdown]
# **Ip/Op Creation**
#
# The inputs and outputs for the model training are specified in it.

# %%
ip=adt.drop('Salary',axis=1)
#all the data columns of the 'adt' dataset, except the column 'Salary'

op=adt.Salary
#only the 'Salary' column of the 'adt' dataset

# %% [markdown]
# **ML Model Training and Prediction- Linear Regression**
#
# This code takes an approach where the 'Train Test Split', 'Standard Scaler', 'Model Training', 'Prediction' and 'Accuracy' check are merged togther and put inside a loop, so as to find the optimum value of 'random_state', where we get the maximum values for 'accuracy','precision' and 'recall'.
#
#
# However, as we are using a categorical dataset, our Linear Regression Model will show us error in conversion metrics.

# %%
#maxip=0       #stores the random_state at which the precision is maximum
#maxir=0       #stores the random_state at which the recall is maximum
#maxacc=0      #stores the value of maximum accuracy
#maxpre=0      #stores the value of maximum precision
#maxrec=0      #stores the value of maximum recall
#for i in range(0,201):                        #checks random_state from 0 to 200
#    from sklearn.model_selection import train_test_split
#    x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=0.35,random_state=i)
#    #the input data and the output data are divied in categories of 'training' and 'testing'
#    #while 'x' represents the training data, y represents the testing data
#    #'x_train' represents input training values, x_test represents input testing values
#    from sklearn.preprocessing import StandardScaler
#    sc = StandardScaler()
#    x_train = sc.fit_transform(x_train)    
#    x_test = sc.fit_transform(x_test)
#    #as the input columns are having huge variation in ranges, we scale them to a generalized range
#    #StandardScaler removes the mean and scales each feature/variable to unit variance
#    from sklearn.linear_model import LinearRegression
#    lr = LinearRegression()
#    lr.fit(x_train,y_train)
#    #the model is trained using Linear Regression and the data is fitted into the model
#    yp = lr.predict(x_test)
#    #prediction is made using the testing data
#    print('\nFor',i,'random state:')
#    from sklearn import metrics
#    acc = metrics.accuracy_score(y_test,yp)
#    print('Accuracy is:',acc)
#    if acc>maxacc:
#        maxacc=acc
#        maxia=i
#    pre = metrics.precision_score(y_test,yp,average='weighted')
#    print('Precision is:',pre)
#    if pre>maxpre:
#        maxpre=pre
#        maxip=i
#    recall = metrics.recall_score(y_test,yp,average='weighted')
#    print('Recall is:',recall)
#    if recall>maxrec:
#        maxrec=recall
#        maxir=i
#print('\n\nMax Accuracy at',maxia,'random state with Accuracy=',maxacc)
#print('\nMax Precision at',maxip,'random state with Precision=',maxpre)
#print('\nMax Recall at',maxir,'random state with Recall=',maxrec)

#the accuracy,precision and recall are the value comparisons using different metrics

# %% [markdown]
# **Model Training using Logistic Regression and Label encoding**
#
# The Logistic Regression is often applied using 'One-Hot Encoding'. The challenge that I faced in this particular dataset is that there were a large number of strings data, thus converting them all and storing them in one nd array was troblesome.
#
# The above problem was reflected while going for the 'train_test_split', just after the encoding the datas
#
# **Real-time Error Message:**
#
# Singleton array array(<32561x104 sparse matrix of type '<class 'numpy.float64'>'
# 	with 362402 stored elements in Compressed Sparse Row format>,
#       dtype=object) cannot be considered a valid collection.

# %% [markdown]
# A conclusion thus can be drawn to try and use other methods of encoding.
#
# In this below example, as a continuation of the previously encoded values, we would use 'Label-Encoding' for Logistic Regression and analysis the accuracy that can be achieved by altering the random states.
#
# However, this method is not recommmended.
#
# The value at each iteration has not been printed, so as to avoid clumsy outputs. The user, however, may print the output at each iteration, so as to analyse the variation in each combination.

# %%
maxia=0       #stores the random_state at which the accuracy is maximum
maxip=0       #stores the random_state at which the precision is maximum
maxir=0       #stores the random_state at which the recall is maximum
maxif=0       #stores the random_state at which the F1_score is maximum
maxacc=0      #stores the value of maximum accuracy
maxpre=0      #stores the value of maximum precision
maxrec=0      #stores the value of maximum recall
maxf1=0      #stores the value of maximum f1_score

for i in range(0,101):                        #checks random_state from 0 to 100, finds the most optimum value
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=0.35,random_state=i)
    #the input data and the output data are divied in categories of 'training' and 'testing'
    #while 'x' represents the training data, y represents the testing data
    #'x_train' represents input training values, x_test represents input testing values
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    x_train = sc.fit_transform(x_train)    
    x_test = sc.fit_transform(x_test)
    #as the input columns are having huge variation in ranges, we scale them to a generalized range
    #StandardScaler removes the mean and scales each feature/variable to unit variance
    from sklearn.linear_model import LogisticRegression
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    #the model is trained using Logistic Regression and the data is fitted into the model
    yp = lr.predict(x_test)
    #prediction is made using the testing data
    from sklearn import metrics
    acc = metrics.accuracy_score(y_test,yp)
    if acc>maxacc:
        maxacc=acc            #stores the maximum value for 'accuracy'
        maxia=i
    pre = metrics.precision_score(y_test,yp,average='weighted')
    if pre>maxpre:
        maxpre=pre           #stores the maximum value for 'precision'
        maxip=i
    recall = metrics.recall_score(y_test,yp,average='macro')
    if recall>maxrec:
        maxrec=recall         #stores the maximum value for 'recall'
        maxir=i
    f1 = metrics.f1_score(y_test,yp,average='macro')
    if f1>maxf1:
        maxf1=f1              #stores the maximum value for 'f1-score'
        maxif=i
print('\n\nMax Accuracy at',maxia,'random state with Accuracy=',maxacc)
print('\nMax Precision at',maxip,'random state with Precision=',maxpre)
print('\nMax Recall at',maxir,'random state with Recall=',maxrec)
print('\nMax F1-score at',maxif,'random state with F1-score=',maxf1)


#the accuracy,precision and recall are the value comparisons using different metrics
#'F1_score' is a harmonic mean of 'precision' and 'recall', thus can be used to represent both
#in further analysis, 'recall' and 'precision' will be dropped and just 'f1_score' would be used to represent both
#a detailed overview on each of them can be found in the documentations of 'scikit-learn'
# Out:
# Max Accuracy at 27 random state with Accuracy= 0.8321488110906379
#
# Max Precision at 27 random state with Precision= 0.8217550655326944
#
# Max Recall at 15 random state with Recall= 0.7096014089729329
#
# Max F1-score at 15 random state with F1-score= 0.7341952440429307

# %% [markdown]
# **Model Training using Gaussian NB and Label Encoding**
#
# A continuation of the above encoded input and output values is taken here also.
#
# This method uses one the Naive Bayes model, where we take into consideration conditional probabilistic approach and Gaussian distribution. Gaussian Naive Bayes assumes that each parameter (also called features or predictors) has an independent capacity of predicting the output variable. The advantage of such an approach is that it doesn't require as much training data. It handles both continuous and discrete data. It is highly scalable with the number of predictors and data points. It is fast and can be used to make real-time predictions. Datasets like the one in this example, are yeild good and reak results when solved with NB, KNN and SVM.
#
# However, in the below approach proper amount of analysed data has been provided to the model for analysis and prediction.
#
# The data is being judged over different combination of 'test sizes' and 'random states'. Two of the metrics: 'accuracy' and 'f1 score' is taken into consideration for making justice to each combination.
#
# The test size includes floating numbers and its range is generally between 0.2-0.35, thus a list of some common test sizes are taken.
#
# The value at each iteration has not been printed, so as to avoid clumsy outputs. The user, however, may print the output at each iteration, so as to analyse the variation in each combination.

# %%
maxia=0       #stores the random_state at which the accuracy is maximum
maxif=0       #stores the random_state at which the f1_score is maximum
maxja=0       #stores the test_size at which the accuracy is maximum
maxjf=0       #stores the test_size at which the f1_score is maximum
maxacc=0      #stores the value of maximum accuracy
maxf1=0      #stores the value of maximum f1_score

for j in [0.25,0.3,0.35]:                                    #checks the test size in a certain range
    for i in range(0,51):                                    #checks random_state from 0 to 50
        from sklearn.model_selection import train_test_split
        x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=j,random_state=i)
        from sklearn.preprocessing import StandardScaler
        sc = StandardScaler()
        x_train = sc.fit_transform(x_train)    
        x_test = sc.fit_transform(x_test)
        from sklearn.naive_bayes import GaussianNB
        clf=GaussianNB()
        clf.fit(x_train,y_train)
        yp=clf.predict(x_test)        #predict the data
        from sklearn import metrics
        acc = metrics.accuracy_score(y_test,yp)
        if acc>maxacc:
            maxacc=acc              #stores the maximum value for 'accuracy'
            maxia=i
            maxja=j
        f1 = metrics.f1_score(y_test,yp,average='macro')
        if f1>maxf1:
            maxf1=f1                #stores the maximum value for 'f1-score'
            maxif=i
            maxjf=j
print('\n\nMax Accuracy at',maxia,'random state and at',maxja,'test size with Accuracy=',maxacc)
print('\nMax Precision at',maxif,'random state and at',maxjf,'test size with Precision=',maxf1)

#Gaussian Naive Base is based on conditional probability, uses bayes' theorem
#first a event frequency table/matrix is build
#a likelihood table of event dependencies is used
#Gaussian NB is good when both text data and numeric data are involved
# Out:
# Max Accuracy at 32 random state and at 0.25 test size with Accuracy= 0.8143962658150105
#
# Max Precision at 50 random state and at 0.35 test size with Precision= 0.6913335843778579

# %% [markdown]
# **Model Training using K-Nearest Neighbors and Label Encoding**
#
# The model is still using previously encoded values of input and output for model training.
#
# Naive Bayes is a linear classifier while K-NN is not; It tends to be faster when applied to big data. In comparison, k-nn is usually slower for large amounts of data, because of the calculations required for each new step in the process. If speed is important, choose Naive Bayes over K-NN.
#
# The main advantage of KNN over other algorithms is that KNN can be used for multiclass classification. Therefore if the data consists of more than two labels or in simple words if you are required to classify the data in more than two categories then KNN can be a suitable algorithm.
#
# KNN is sensitive to noise, so accurate data preprocessing must be done. KNN employs instance-based learning and is a lazy algorithm that refers to an algorithm that does not learn anything from the dataset. Space complexity refers to the total memory used by the algorithm. If we have n data points in training and each point is of m dimension. Then time complexity is of order O(nm), which will be huge if we have higher dimension data. Therefore, KNN is not suitable for high dimensional data.
#
# KNN is commonly used for simple recommendation systems, pattern recognition, data mining, financial market predictions, intrusion detection, and more. In order to determine which data points are closest to a given query point, the distance between the query point and the other data points will need to be calculated.
#
# In the below application of KNN, the 'n_neighbors' are varied in  the range of 1 to 10, to get the optimum k-value. To reduce the time complexities, the ranges of 'test_split' and 'random_state' are reduced.
#
# The value at each iteration has not been printed, so as to avoid clumsy outputs. The user, however, may print the output at each iteration, so as to analyse the variation in each combination.

# %%
maxia=0       #stores the random_state at which the accuracy is maximum
maxif=0       #stores the random_state at which the f1_score is maximum
maxja=0       #stores the test_size at which the accuracy is maximum
maxjf=0       #stores the test_size at which the f1_score is maximum
maxka=0       #stores the n_neighbors value at which the accuracy is maximum
maxkf=0       #stores the n_neighbors value at which the f1_score is maximum
maxacc=0      #stores the value of maximum accuracy
maxf1=0      #stores the value of maximum f1_score

for j in [0.2,0.25,0.3]:                                     #checks the test_size in a certain range
    for i in range(0,31):                                    #checks random_state from 0 to 30
        from sklearn.model_selection import train_test_split
        x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=j,random_state=i)
        from sklearn.preprocessing import StandardScaler
        sc = StandardScaler()
        x_train = sc.fit_transform(x_train)    
        x_test = sc.fit_transform(x_test)
        for k in range(1,10):                                #checks k_neighbors from 0 to 10
            from sklearn.neighbors import KNeighborsClassifier
            alg = KNeighborsClassifier(n_neighbors=k)
            alg.fit(x_train,y_train)
            yp=alg.predict(x_test)        #predict the data
            from sklearn import metrics
            acc = metrics.accuracy_score(y_test,yp)
            if acc>maxacc:
                maxacc=acc               #stores the maximum value for 'accuracy'
                maxia=i
                maxja=j
                maxka=k
            f1 = metrics.f1_score(y_test,yp,average='macro')
            if f1>maxf1:
                maxf1=f1                #stores the maximum value for 'f1-score'
                maxif=i
                maxjf=j
                maxkf=k
print('\n\nMax Accuracy at',maxia,'random state, at',maxka,'n_neighbors and',maxja,'test size with Accuracy=',maxacc)
print('\nMax Precision at',maxif,'random state, at',maxkf,'n_neighbors and',maxjf,'test size with Precision=',maxf1)

#KNN is based on similarity concept
#euclidean distance is used to find the density of nearby points, based on their category
#the optimum distance is used, and the majority categorical points tell about the new point category
#examples of this model are recommendation system, search engine etc
# Out:
# Max Accuracy at 8 random state, at 9 n_neighbors and 0.2 test size with Accuracy= 0.84692154153232
#
# Max Precision at 8 random state, at 9 n_neighbors and 0.2 test size with Precision= 0.7770550788675614

# %% [markdown]
# **Model Training Using Support Vector Machine and Label Encoding**
#
# For this analysis too, we will be using the already label-encoded values.
#
# A support vector machine (SVM) is a type of deep learning algorithm that performs supervised learning for classification or regression of data groups. In AI and machine learning, supervised learning systems provide both input and desired output data, which are labeled for classification. It is robust to outliers. Decision model can be easily updated. It has excellent generalization capability, with high prediction accuracy. Its implementation is easy. While both kNN and SVM algorithms yield positive results regarding the accuracy in which they classify the images, the SVM provides significantly better classification accuracy and classification speed than the kNN.
#
# For this below stated example, along with the different combinations of 'test_size' and 'sample_space', we will alter the values for the 'kernel coefficient' and 'penalty parameter', so that the optimum accuracy can be achieved.
#
# The value at each iteration has not been printed, so as to avoid clumsy outputs. The user, however, may print the output at each iteration, so as to analyse the variation in each combination.

# %%
maxia=0       #stores the random_state at which the accuracy is maximum
maxif=0       #stores the random_state at which the f1_score is maximum
maxja=0       #stores the test_size at which the accuracy is maximum
maxjf=0       #stores the test_size at which the f1_score is maximum
maxka=0       #stores value of error optimization factor for which the accuracy is maximum
maxkf=0       #stores value of error optimization factor for which the f1_score is maximum
maxla=0       #stores value of kernel coefficient for which the accuracy is maximum
maxlf=0       #stores value of kernel coefficient for which the f1_score is maximum
maxacc=0      #stores the value of maximum accuracy
maxf1=0       #stores the value of maximum f1_score

for j in [0.25,0.3,0.35]:                                        #checks the test size for values of 0.25, 0.3 and 0.35
    for i in range(0,11):                                        #checks random_state from 0 to 10
        from sklearn.model_selection import train_test_split
        x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=j,random_state=i)
        from sklearn.preprocessing import StandardScaler
        sc = StandardScaler()
        x_train = sc.fit_transform(x_train)    
        x_test = sc.fit_transform(x_test)
        for k in [400,500]:                       #checks for 'penalty parameter' for values of 400 and 500
            for l in [0.01, 0.1,1]:                 #checks for 'kernel coefficient' for values 0.01 and 0.1
                from sklearn import svm
                alg = svm.SVC(kernel='rbf',C=k,gamma=l)
                alg.fit(x_train,y_train)
                yp=alg.predict(x_test)            #predict the data
                from sklearn import metrics
                acc = metrics.accuracy_score(y_test,yp)
                if acc>maxacc:
                    maxacc=acc                    #stores the maximum value for 'accuracy'
                    maxia=i
                    maxja=j
                    maxka=k
                    maxla=l
                f1 = metrics.f1_score(y_test,yp,average='macro')
                if f1>maxf1:
                    maxf1=f1                      #stores the maximum value for 'f1-score'
                    maxif=i
                    maxjf=j
                    maxkf=k
                    maxlf=l
print('\n\nMax Accuracy at',maxia,'random state, at',maxka,'penalty parameter,',maxla,'kernel coefficient',maxja,'test size with Accuracy=',maxacc)
print('\nMax Precision at',maxif,'random state, at',maxkf,'penalty parameter,',maxlf,'kernel coefficient',maxjf,'test size with F1_Score=',maxf1)

#SVM->support vector machine
#classifies categories using hyperline(best-fit line)->separates group
#initially a random line is generated for finding the support vector
#hyperline-> perpendicular distance from support vectors, also known as margin, should be maximum
#support vectors-> points of categories, close to the hyperline or hyper plane
#to convert 1-d points to 2-d points, we use kernel functions:
#linear, polynomial and rbf(radial basis function)
#for 3-d, we convert the 2-d, and then use a hyper-plane
#in svm, the execution time is more
#for complex data, yeild better results
#can be used for both regression and classification
#'gamma'-> kernel coefficient 
#'C'->error optimization/penalty parameter->generally between 1 to 1000
# Out:
# Max Accuracy at 9 random state, at 400 penalty parameter, 0.01 kernel coefficient 0.25 test size with Accuracy= 0.855791671784793
#
# Max Precision at 9 random state, at 400 penalty parameter, 0.01 kernel coefficient 0.25 test size with F1_Score= 0.7790914952504436
